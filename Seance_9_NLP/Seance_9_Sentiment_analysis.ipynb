# %% [markdown]
# # Detection de sentiment
#
# Dans ce TP, nous analysons — avec son consentement explicite — les posts FR/EN de Toto publiés sur Instagram, LinkedIn et Facebook afin d’estimer un pouls d’humeur agrégé au fil du temps. L’objectif n’est pas clinique ni individuel, mais pédagogique : nettoyer les textes, appliquer un modèle de sentiment adapté

# %%
# Télécharger le fichier CSV directement depuis GitHub
# !wget https://raw.githubusercontent.com/bidoscar/AFRICITIZEN-ACDS-Coding/main/Seance_9_NLP/Datasets/df_simulated_posts_emotions.xlsx

# %%
import pandas as pd
import numpy as np
import re
import string
import unicodedata
from collections import Counter
import matplotlib.pyplot as plt
from pathlib import Path

# 1) Load the Excel
path = Path("df_simulated_posts_emotions.xlsx")
df = pd.read_excel(path)

print(df.shape)
df.head(10)
